# %% [markdown]
# <a href="https://colab.research.google.com/github/Ranjan4Kumar/Text-To-Speech-gTTs-model-/blob/main/Text_to_Speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install

# %%
from gtts import gTTS
from IPython.display import Audio
import pandas as pd
tts = gTTS(input("Enter your sentence"))
tts.save('1.wav')
sound_file = '1.wav'
Audio(sound_file,autoplay = True)
# Out:
# Enter your sentenceRunnin' up that sack Smokin' on this dope, also known as pack And we got them gats, we won't cut no slack In these Fendi slacks, I be speakin' facts I'm all about a stack Big ass blunts of thracks, and that be the OG, just to be exact She like how I flex, so she want some sex I don't wanna talk She don't wanna text
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
